# %% [markdown]
# <a href="https://colab.research.google.com/github/mundhra08/DS_Practicals/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Python Libraries

import numpy as np

import scipy as sp

import pandas as pd

import matplotlib.pyplot as mpl

import seaborn as sns

# %%
df = pd.read_csv("/StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none        90.0           95.0           93.0
# 3                    none        47.0           57.0           44.0
# 4                    none        76.0           78.0           75.0

# %%
df.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                     float64
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# ...

# %%
df['gender'].dtype
# Out:
# dtype('O')

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  995.000000     995.000000     990.000000
# mean    66.194975      69.202010      68.166667
# std     15.109932      14.623181      15.053914
# min      0.000000      17.000000      15.000000
# 25%     57.000000      59.000000      58.000000
# 50%     66.000000      70.000000      69.000000
# 75%     77.000000      79.500000      79.000000
# max    100.000000     100.000000     100.000000

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=1000, step=1),
#  Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#         'test preparation course', 'math score', 'reading score',
#         'writing score'],
#        dtype='object')]

# %%
df.size
# Out:
# 8000

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.values
# Out:
# array([['female', 'group B', "bachelor's degree", ..., 72.0, 72.0, 74.0],
#        ['female', 'group C', 'some college', ..., 69.0, 90.0, 88.0],
#        ['female', 'group B', "master's degree", ..., 90.0, 95.0, 93.0],
#        ...,
#        ['female', 'group C', 'high school', ..., 59.0, 71.0, 65.0],
#        ['female', 'group D', 'some college', ..., 68.0, 78.0, 77.0],
#        ['female', 'group D', 'some college', ..., 77.0, 86.0, 86.0]],
#       dtype=object)

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.median()
# Out:
# <ipython-input-159-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# math score       66.0
# reading score    70.0
# writing score    69.0
# dtype: float64

# %%
#df.mean()
df.head(50).mean()
# Out:
# <ipython-input-160-c6573d64182f>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.head(50).mean()
# math score       62.840000
# reading score    68.533333
# writing score    66.440000
# dtype: float64

# %%
df.mode()
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group C                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none        65.0           72.0           74.0

# %%
df.max()
# Out:
# <ipython-input-162-4c1ddf8920ff>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max()
# gender                                     male
# parental level of education    some high school
# lunch                                  standard
# test preparation course                    none
# math score                                100.0
# reading score                             100.0
# writing score                             100.0
# dtype: object

# %%
df.min()
# Out:
# <ipython-input-163-c3612c624a3f>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min()
# gender                                     female
# parental level of education    associate's degree
# lunch                                free/reduced
# test preparation course                 completed
# math score                                    0.0
# reading score                                17.0
# writing score                                15.0
# dtype: object

# %%
df.sample()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 780  female        group D          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 780                    none        46.0           56.0           57.0

# %%
df.std()
# Out:
# <ipython-input-165-ce97bb7eaef8>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# math score       15.109932
# reading score    14.623181
# writing score    15.053914
# dtype: float64

# %%
df.dropna()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.tail(5)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed        88.0           99.0           95.0
# 996                    none        62.0           55.0           55.0
# 997               completed        59.0           71.0           65.0
# 998               completed        68.0           78.0           77.0
# 999                    none        77.0           86.0           86.0

# %%
df_lunch=df.groupby(['lunch'])

# %%
df_lunch.mean()
# Out:
# <ipython-input-169-bb36cea2fce9>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_lunch.mean()
#               math score  reading score  writing score
# lunch
# free/reduced   59.008523      64.687500      63.243553
# standard       70.129082      71.673406      70.847114

# %%
df.groupby("lunch")[["math score"]].mean()
# Out:
#               math score
# lunch
# free/reduced   59.008523
# standard       70.129082

# %%
df.groupby(["lunch"],sort=True)[["math score"]].mean()
# Out:
#               math score
# lunch
# free/reduced   59.008523
# standard       70.129082

# %%
df_sub1=df[df['math score']>80]
df_sub1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 16     male        group C                 high school      standard
# 34     male        group E                some college      standard
# 35     male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 979  female        group C          associate's degree      standard
# 981    male        group D            some high school      standard
# 987    male        group E            some high school      standard
# 990    male        group E                 high school  free/reduced
# 995  female        group E             master's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df_sub=df[df['race/ethnicity']=="group E"]
df_sub
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 32   female        group E             master's degree  free/reduced
# 34     male        group E                some college      standard
# 35     male        group E          associate's degree      standard
# 44   female        group E          associate's degree  free/reduced
# 50     male        group E                some college      standard
# ..      ...            ...                         ...           ...
# 962  female        group E          associate's degree      standard
# 968  female        group E          associate's degree      standard
# 987    male        group E            some high school      standard
# 990    male        group E                 high school  free/reduced
# 995  female        group E             master's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df[['math score','reading score','writing score']]
# Out:
#      math score  reading score  writing score
# 0          72.0           72.0           74.0
# 1          69.0           90.0           88.0
# 2          90.0           95.0           93.0
# 3          47.0           57.0           44.0
# 4          76.0           78.0           75.0
# ..          ...            ...            ...
# 995        88.0           99.0           95.0
# 996        62.0           55.0           55.0
# 997        59.0           71.0           65.0
# 998        68.0           78.0           77.0
# 999        77.0           86.0           86.0
#
# [1000 rows x 3 columns]

# %%
df[10:20]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# 13    male        group A                some college      standard
# 14  female        group A             master's degree      standard
# 15  female        group C            some high school      standard
# 16    male        group C                 high school      standard
# 17  female        group B            some high school  free/reduced
# 18    male        group C             master's degree  free/reduced
# 19  female        group C          associate's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 10                    none        58.0           54.0           52.0
# 11                    none        40.0           52.0           43.0
# ...

# %%
df.loc[10:20,['math score',]]
# Out:
#     math score
# 10        58.0
# 11        40.0
# 12        65.0
# 13        78.0
# 14        50.0
# 15        69.0
# 16        88.0
# 17        18.0
# 18        46.0
# 19        54.0
# 20        66.0

# %%
df.iloc[10:20,[0,1,2]]
# Out:
#     gender race/ethnicity parental level of education
# 10    male        group C          associate's degree
# 11    male        group D          associate's degree
# 12  female        group B                 high school
# 13    male        group A                some college
# 14  female        group A             master's degree
# 15  female        group C            some high school
# 16    male        group C                 high school
# 17  female        group B            some high school
# 18    male        group C             master's degree
# 19  female        group C          associate's degree

# %%
#df.iloc[0]
#df.iloc[-1]
df.iloc[10:20,0:2]
# Out:
#     gender race/ethnicity
# 10    male        group C
# 11    male        group D
# 12  female        group B
# 13    male        group A
# 14  female        group A
# 15  female        group C
# 16    male        group C
# 17  female        group B
# 18    male        group C
# 19  female        group C

# %%
df.iloc[[10,20],[6,7]]
# Out:
#     reading score  writing score
# 10           54.0           52.0
# 20           69.0           63.0

# %%
sort1=df.sort_values(by='math score')
sort1.head(5)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 59                     none         0.0           17.0            NaN
# 980                    none         8.0           24.0           23.0
# 17                     none        18.0           32.0           28.0
# 787                    none        19.0           38.0           32.0
# 145                    none        22.0           39.0           33.0

# %%
sort2= df.sort_values(by = ['writing score','reading score',])
sort2.head()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 596    male        group B                 high school  free/reduced
# 327    male        group A                some college  free/reduced
# 76     male        group E            some high school      standard
# 980  female        group B                 high school  free/reduced
# 211    male        group C                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 596                    none        30.0           24.0           15.0
# 327                    none        28.0           23.0           19.0
# 76                     none         NaN           26.0           22.0
# 980                    none         8.0           24.0           23.0
# 211                    none        35.0           28.0           27.0

# %%
df.isnull().sum()
# Out:
# gender                          0
# race/ethnicity                  2
# parental level of education     0
# lunch                           0
# test preparation course         0
# math score                      5
# reading score                   5
# writing score                  10
# dtype: int64

# %%
df.isnull()
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.dropna()
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.iloc[40:50].dropna(how='all')
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 40    male        group C          associate's degree  free/reduced
# 41  female        group C          associate's degree      standard
# 42  female        group B          associate's degree      standard
# 43    male        group B                some college  free/reduced
# 44  female        group E          associate's degree  free/reduced
# 45    male        group B          associate's degree      standard
# 46  female        group A          associate's degree      standard
# 47  female        group C                 high school      standard
# 48  female        group D          associate's degree  free/reduced
# 49    male        group C                 high school      standard
#
#    test preparation course  math score  reading score  writing score
# 40                    none        55.0            NaN           54.0
# 41                    none        58.0            NaN           68.0
# ...

# %%
df.iloc[40:50].fillna(df['reading score'].median())
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 40    male        group C          associate's degree  free/reduced
# 41  female        group C          associate's degree      standard
# 42  female        group B          associate's degree      standard
# 43    male        group B                some college  free/reduced
# 44  female        group E          associate's degree  free/reduced
# 45    male        group B          associate's degree      standard
# 46  female        group A          associate's degree      standard
# 47  female        group C                 high school      standard
# 48  female        group D          associate's degree  free/reduced
# 49    male        group C                 high school      standard
#
#    test preparation course  math score  reading score  writing score
# 40                    none        55.0           70.0           54.0
# 41                    none        58.0           70.0           68.0
# ...

# %%
df.iloc[40:50].notnull()
# Out:
#     gender  race/ethnicity  parental level of education  lunch  \
# 40    True            True                         True   True
# 41    True            True                         True   True
# 42    True            True                         True   True
# 43    True            True                         True   True
# 44    True            True                         True   True
# 45    True            True                         True   True
# 46    True            True                         True   True
# 47    True            True                         True   True
# 48    True            True                         True   True
# 49    True            True                         True   True
#
#     test preparation course  math score  reading score  writing score
# 40                     True        True          False           True
# 41                     True        True          False           True
# ...

# %%
df[['math score','reading score']].agg(['min','max','mean'])
# Out:
#       math score  reading score
# min     0.000000       17.00000
# max   100.000000      100.00000
# mean   66.194975       69.20201

# %%
df.sem()
# Out:
# <ipython-input-200-dc340ca8b010>:1: FutureWarning: The default value of numeric_only in DataFrame.sem is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.sem()
# math score       0.479017
# reading score    0.463586
# writing score    0.478445
# dtype: float64

# %%
df.var()
# Out:
# <ipython-input-201-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# math score       228.310035
# reading score    213.837421
# writing score    226.620324
# dtype: float64

# %%
df.skew()
# Out:
# <ipython-input-202-9e0b1e29546f>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# math score      -0.281397
# reading score   -0.264604
# writing score   -0.249543
# dtype: float64

# %%
df.kurt()
# Out:
# <ipython-input-203-8bd0d54cd88d>:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.kurt()
# math score       0.298929
# reading score   -0.070724
# writing score   -0.148685
# dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-205-ce400e08cc7c> in <cell line: 1>()
# ----> 1 df.displot
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'displot'

# %%
mpl.bar(df['math score'].head(),5)
# Out:
# <BarContainer object of 5 artists>
